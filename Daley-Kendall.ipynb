# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# Daley-Kendall model for information spread
def daley_kendall_info(t, y, alpha, beta, gamma):
    S, I, R = y
    dS_dt = -beta * S * I
    dI_dt = beta * S * I - alpha * I
    dR_dt = gamma * I
    return [dS_dt, dI_dt, dR_dt]

# Parameters
def set_parameters(alpha, beta, gamma):
    return [alpha, beta, gamma]

# Initial conditions
def set_initial_conditions(S0, I0, R0):
    return [S0, I0, R0]

# Solve the system of ODEs
def solve_model(alpha, beta, gamma, S0, I0, R0,t_span,t_eval):
    t_span = (0, t_span)
    t_eval = np.linspace(*t_span, t_eval)
    initial_conditions = set_initial_conditions(S0, I0, R0)
    solution = solve_ivp(
        daley_kendall_info,
        t_span,
        initial_conditions,
        args=set_parameters(alpha, beta, gamma),
        t_eval=t_eval,
    )
    return solution

# Plot spreaders, ignorants, and stiflers
def plot_results(solution):
    plt.figure(figsize=(8, 4))
    plt.plot(solution.t, solution.y[0], lw = 2.6, label='Spreaders (S)', color='b')
    plt.plot(solution.t, solution.y[1], lw = 2.6, label='Ignorants (I)', color='r')
    plt.plot(solution.t, solution.y[2], lw = 2.6, label='Stiflers (R)', color='g')
    plt.xlabel('Time')
    plt.ylabel('Population')
    plt.legend()
    plt.title('Daley-Kendall Information Spread Model')
    plt.grid(True, alpha = 0.3)
    plt.savefig('figure1.png')
    plt.show()
    # plt.savefig("1.png")

## Solution of the model
# Parameters
alpha = 0.1   # Rate at which ignorants become stiflers
beta = 0.3    # Rate at which spreaders influence ignorants
gamma = 0.05  # Rate at which ignorants become stiflers (bored)

# Initial conditions
S0 = 0.8  # Initial spreaders
I0 = 0.1  # Initial ignorants
R0 = 0.1  # Initial stiflers

# Time span
t_span = 100
t_eval = 1000

solution = solve_model(alpha, beta, gamma, S0, I0, R0, t_span, t_eval)
plot_results(solution)

# %%
# put any new or modified code here!
plt.figure(figsize=(8, 4))
plt.plot(solution.y[0], solution.y[1], lw = 2.5, label='Spreaders (S) vs Ignorants (I)', color='b')
plt.plot(solution.y[1], solution.y[2], lw = 2.5, label='Ignorants (I) vs Stiflers (R)', color='r')
plt.plot(solution.y[0], solution.y[2], lw = 2.5, label='Spreaders (S) vs Stiflers (R)', color='g')
plt.xlabel('Population')
plt.ylabel('Population')
plt.legend()
plt.title('Daley-Kendall Information Spread Model')
plt.grid(True, alpha = 0.3)
plt.show()
plt.savefig('figure2.png')

# %%
# Daley-Kendall model for information spread
def daley_kendall_info_1(t, y, alpha, beta, gamma, zeta):
    S, I, R = y
    dS_dt = -beta * S * I
    dI_dt = beta * S * I - alpha * I + zeta * R
    dR_dt = gamma * I - zeta * R
    return [dS_dt, dI_dt, dR_dt]

# Parameters
alpha = 0.1   # Rate at which ignorants become stiflers
beta = 0.3    # Rate at which spreaders influence ignorants
gamma = 0.05  # Rate at which ignorants become stiflers (bored)
zeta = 0.1 # Rate at which siflers are converted to ignorants 

# Initial conditions
S0 = 0.8  # Initial spreaders
I0 = 0.1  # Initial ignorants
R0 = 0.1  # Initial stiflers
initial_conditions = [S0, I0, R0]

# Time span
t_span = (0, 100)
t_eval = np.linspace(*t_span, 1000)

# Solve the system of ODEs
solution = solve_ivp(
    daley_kendall_info_1,
    t_span,
    initial_conditions,
    args=(alpha, beta, gamma, zeta),
    t_eval=t_eval,
)

# Plot spreaders, ignorants, and stiflers
plt.figure(figsize=(8, 4))
plt.plot(solution.t, solution.y[0], lw = 2.5, label='Spreaders (S)', color='b')
plt.plot(solution.t, solution.y[1], lw = 2.5, label='Ignorants (I)', color='r')
plt.plot(solution.t, solution.y[2], lw = 2.5, label='Stiflers (R)', color='g')
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.title('People are converting from R to I, zeta = 0.1')
plt.grid(True, alpha = 0.3)
plt.show()
